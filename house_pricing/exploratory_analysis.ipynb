# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math

# %% [markdown]
# # House Prices: Advanced Regression Techniques
# Predict sales prices and practice feature engineering, RFs, and gradient boosting
#
# ### Start here if...
# You have some experience with R or Python and machine learning basics. This is a perfect competition for data science students who have completed an online course in machine learning and are looking to expand their skill set before trying a featured competition.
#
# ### Competition Description
#
#
# Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
#
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
#
# ### Practice Skills
# * Creative feature engineering
# * Advanced regression techniques like random forest and gradient boosting
# * Acknowledgments
# * The Ames Housing dataset was compiled by Dean De Cock for use in data science education. It's an incredible alternative for data scientists looking for a modernized and expanded version of the often cited Boston Housing dataset.

# %%
# read data
house_pricing_train = pd.read_csv('input/train.csv')
house_pricing_test = pd.read_csv('input/test.csv')
,
print("Train size: ",len(house_pricing_train))
print("Test size: ",len(house_pricing_test))

house_pricing_train.describe()
# Out:
# Train size:  1460
# Test size:  1459
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# ...

# %% [markdown]
# ## Analysing the response variable: SalePrice

# %%
fig, ax = plt.subplots(1,2, figsize=(15,3))
house_pricing_train.SalePrice.hist(ax=ax[0])
house_pricing_train.boxplot(['SalePrice'], ax=ax[1])

print(house_pricing_train.SalePrice.describe())
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### What are the numerical features and how they correlate to SalePrice?
#
# The idea is to start small analysing just the numerical columns that are most correlated to the response (SalesPrice)

# %%
house_pricing_train.select_dtypes(include='number').columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
# calculate correlation
corr = house_pricing_train.corr()

numerical_correlation = corr[corr['SalePrice']>0.60]['SalePrice'].sort_values(ascending=False)[1:]
print(numerical_correlation)
correlated_numerical_columns = numerical_correlation.index.to_list()
# Out:
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Wow... so many features highly correlated
#
# Maybe just using Linear regression we could reach a good accuracy...

# %%
from sklearn.linear_model import LinearRegression

X = house_pricing_train[correlated_numerical_columns]
y = house_pricing_train['SalePrice']

linear_model = LinearRegression().fit(X, y)
print(linear_model.score(X, y))

plt.scatter(y, linear_model.predict(X))
plt.plot(y, y, color='red')
# Out:
# 0.7619179511862831

# %% [markdown]
# ### Maybe the Multicollinearity could be hurting the Linear Model
#
# Let's check the correlation between features

# %%
X.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_32611c1e_bf1d_11ea_8ba2_c3de3f3fe42drow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_32611c1e_bf1d_11ea_8ba2_c3de3f3fe42drow0_col1 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_32611c1e_bf1d_11ea_8ba2_c3de3f3fe42drow0_col2 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_32611c1e_bf1d_11ea_8ba2_c3de3f3fe42drow0_col3 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_32611c1e_bf1d_11ea_8ba2_c3de3f3fe42drow0_col4 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_32611c1e_bf1d_11ea_8ba2_c3de3f3fe42drow0_col5 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_32611c1e_bf1d_11ea_8ba2_c3de3f3fe42drow1_col0 {
#             background-color:  #84a7fc;
#             color:  #000000;
# ...

# %% [markdown]
# ### GarageCars Vs GarageArea
#
# They are high correlated, but just deleting one of them it's enought?

# %%
fig, ax = plt.subplots(1, 2, figsize =(13, 3))
garage_area_car = house_pricing_train.groupby(['GarageCars']).agg({'GarageArea':'mean'})
ax[0].bar(garage_area_car.index, garage_area_car.GarageArea)
ax[1].hist(house_pricing_train['GarageArea']/house_pricing_train['GarageCars'])
# Out:
# (array([ 98., 760., 441.,  54.,  15.,   5.,   1.,   3.,   1.,   1.]),
#  array([120. , 200.4, 280.8, 361.2, 441.6, 522. , 602.4, 682.8, 763.2,
#         843.6, 924. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### TotalBsmtSF Vs 1stFlrSF
#
# Again, they are very correlated. It's good to just delete one of those? Which one to delete?
#
# Some houses have basement and, those that do, have a high correlation with the 1st floor area.
# Makes all sense, right?

# %%
fig, ax = plt.subplots(1,4, figsize=(18, 3))
house_pricing_train['TotalBsmtSF'].hist(ax = ax[0])
ax[0].set_title('TotalBsmtSF Histogram')
house_pricing_train['1stFlrSF'].hist(ax = ax[1])
ax[1].set_title('1stFlrSF Histogram')
ax[2].scatter(house_pricing_train['TotalBsmtSF'], house_pricing_train['1stFlrSF'])
ax[2].plot(house_pricing_train['1stFlrSF'],house_pricing_train['1stFlrSF'], color='red')
ax[2].set_title('1stFlrSF Vs TotalBsmtSF')
ax[3].hist(house_pricing_train['TotalBsmtSF']/house_pricing_train['1stFlrSF'])
ax[3].set_title('Bsmt1stFloorRatio')
# Out:
# Text(0.5, 1.0, 'Bsmt1stFloorRatio')

# %% [markdown]
# ### Whats is the final decision?
#
# #### GarageCars Vs GarageArea
# * Remove the GarageCars Feature (this feature has less meaning, the GarageArea is more representative)
# * Create a new Feature hasGarage (Boolean)
# * Create a new Feature GarageRatio (GarageArea over GarageCars)
#
# #### TotalBsmtSF Vs 1stFlrSF
# * Remove TotalBsmtSF Feature
# * Create a new Feature hasBasement (Boolean)
# * Create a new Feature Bsm1stFloorRatio (TotalBsmSF over 1stFloorSF)

# %%
house_pricing_train['hasGarage'] = np.where(house_pricing_train.GarageCars>0, 1, 0)
house_pricing_train['GarageRatio'] = house_pricing_train['GarageArea']/house_pricing_train['GarageCars']
house_pricing_train = house_pricing_train.drop(['GarageCars'], axis=1)

correlated_numerical_columns.remove('GarageCars')
correlated_numerical_columns.append('hasGarage')
correlated_numerical_columns.append('GarageRatio')

house_pricing_train['hasBasement'] = np.where(house_pricing_train.TotalBsmtSF>0, 1, 0)
house_pricing_train['Bsmt1stFloorRatio']  = house_pricing_train['TotalBsmtSF']/house_pricing_train['1stFlrSF']
house_pricing_train = house_pricing_train.drop('TotalBsmtSF', axis=1)

correlated_numerical_columns.remove('TotalBsmtSF')
correlated_numerical_columns.append('hasBasement')
correlated_numerical_columns.append('Bsmt1stFloorRatio')

# %% [markdown]
# ### Let's do the LinearRegression again:

# %%
from sklearn.linear_model import LinearRegression

X = house_pricing_train[correlated_numerical_columns].fillna(0)
y = house_pricing_train['SalePrice']

linear_model = LinearRegression().fit(X, y)
print(linear_model.score(X, y))

plt.scatter(y, linear_model.predict(X))
plt.plot(y, y, color='red')
# Out:
# 0.7650610059296201

# %% [markdown]
# ### Final Thoughts
#
# So looks like we improve a little bit or at least we didn't loose any accuracy.
#
# * 0.7619 to 0.7650
#
#
# And, we remove the multicolinearity of the Linear Regression:

# %%
X.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5bede462_bf1e_11ea_8ba2_c3de3f3fe42drow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5bede462_bf1e_11ea_8ba2_c3de3f3fe42drow0_col1 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_5bede462_bf1e_11ea_8ba2_c3de3f3fe42drow0_col2 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_5bede462_bf1e_11ea_8ba2_c3de3f3fe42drow0_col3 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_5bede462_bf1e_11ea_8ba2_c3de3f3fe42drow0_col4 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_5bede462_bf1e_11ea_8ba2_c3de3f3fe42drow0_col5 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_5bede462_bf1e_11ea_8ba2_c3de3f3fe42drow0_col6 {
#             background-color:  #779af7;
#             color:  #000000;
# ...

# %% [markdown]
# ### Let's do see the correlation for other Features

# %%
# upper triangle mask
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
house_pricing_train.select_dtypes(exclude='number').columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')
